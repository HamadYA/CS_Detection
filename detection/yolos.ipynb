# %%
from ultralytics import YOLO

model = YOLO('yolov12s.pt')

results = model.train(data=f'data.yaml', epochs=100)
# Out:
# Ultralytics 8.3.204 🚀 Python-3.9.12 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 16117MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov12s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/ai-17/Documents/CS_Detection/runs/detect/train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1      9344  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2, 1, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1     37120  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2, 1, 4]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 4]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1    345856  ultralytics.nn.modules.block.A2C2f           [768, 256, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     95104  ultralytics.nn.modules.block.A2C2f           [512, 128, 1, False, -1]
#  15                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1    296704  ultralytics.nn.modules.block.A2C2f           [384, 256, 1, False, -1]
#  18                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  21        [14, 17, 20]  1    819795  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# YOLOv12s summary: 272 layers, 9,133,715 parameters, 9,133,699 gradients, 19.6 GFLOPs
#
# Transferred 629/691 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2601.4±836.7 MB/s, size: 26.6 KB)
# train: Scanning /home/ai-17/Documents/CS_Detection/yolo_export/train/labels.cache... 101 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 101/101 393.7Kit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1865.1±844.6 MB/s, size: 30.9 KB)
# val: Scanning /home/ai-17/Documents/CS_Detection/yolo_export/test/labels.cache... 56 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 56/56 60.5Kit/s 0.0s
# Plotting labels to /home/ai-17/Documents/CS_Detection/runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/ai-17/Documents/CS_Detection/runs/detect/train2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      6.15G      3.381      6.926      2.684          5        640: 100% ━━━━━━━━━━━━ 7/7 2.1it/s 3.3s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.2it/s 1.7s0.8s
#                    all         56         89   5.95e-05     0.0112   3.05e-05    6.1e-06
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100       6.7G      3.223       6.01      2.421         15        640: 100% ━━━━━━━━━━━━ 7/7 3.2it/s 2.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.7it/s 0.4s0.8s
#                    all         56         89   0.000754     0.0562   0.000538   0.000211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      6.76G      2.976       3.95      2.211         13        640: 100% ━━━━━━━━━━━━ 7/7 3.1it/s 2.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 5.0it/s 0.4s0.8s
#                    all         56         89    0.00252      0.472    0.00214   0.000682
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      6.77G      2.652       3.16      1.918          8        640: 100% ━━━━━━━━━━━━ 7/7 3.2it/s 2.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.7it/s 0.4s0.8s
#                    all         56         89    0.00107      0.202   0.000668   0.000183
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      6.83G      2.579      3.185      2.143          6        640: 100% ━━━━━━━━━━━━ 7/7 3.1it/s 2.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s0.8s
#                    all         56         89    0.00137      0.258   0.000889   0.000198
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      6.85G      2.198      2.499       1.96          6        640: 100% ━━━━━━━━━━━━ 7/7 3.1it/s 2.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.5it/s 0.4s0.9s
#                    all         56         89    0.00154      0.146   0.000931   0.000284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      6.85G      2.414      2.756      2.164          5        640: 100% ━━━━━━━━━━━━ 7/7 3.1it/s 2.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.6it/s 0.4s0.8s
#                    all         56         89    0.00305      0.573    0.00246   0.000856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      6.85G      2.225      2.451      1.982          5        640: 100% ━━━━━━━━━━━━ 7/7 3.1it/s 2.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 4.2it/s 0.5s0.9s
#                    all         56         89    0.00272     0.0449    0.00107   0.000228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100

#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      7.01G     0.8696     0.5332      1.206          5        640: 100% ━━━━━━━━━━━━ 7/7 1.0it/s 7.3s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s2.8s
#                    all         56         89      0.425      0.112      0.165     0.0708
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      7.01G     0.8958     0.5231      1.179          7        640: 100% ━━━━━━━━━━━━ 7/7 0.8it/s 8.8s1.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.8it/s 2.5s4.8s
#                    all         56         89      0.364      0.124      0.169      0.069
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      7.01G      0.936     0.5505      1.251          7        640: 100% ━━━━━━━━━━━━ 7/7 0.6it/s 12.0s0.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.4it/s 1.4s2.8s
#                    all         56         89       0.39      0.135      0.176     0.0733
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      7.01G     0.8688     0.5367      1.149          6        640: 100% ━━━━━━━━━━━━ 7/7 1.4it/s 5.1s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.1it/s 1.8s3.5s
#                    all         56         89      0.446      0.157      0.184     0.0757
#
# 100 epochs completed in 0.168 hours.
# Optimizer stripped from /home/ai-17/Documents/CS_Detection/runs/detect/train2/weights/last.pt, 18.7MB
# Optimizer stripped from /home/ai-17/Documents/CS_Detection/runs/detect/train2/weights/best.pt, 18.7MB
#
# Validating /home/ai-17/Documents/CS_Detection/runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.204 🚀 Python-3.9.12 torch-2.8.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 16117MiB)
# YOLOv12s summary (fused): 159 layers, 9,111,459 parameters, 0 gradients, 19.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.5it/s 0.6s1.1s
#                    all         56         89      0.551      0.124      0.203     0.0957
# Speed: 0.1ms preprocess, 7.8ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /home/ai-17/Documents/CS_Detection/runs/detect/train2

# %%
from IPython.display import Image

Image(filename=f'runs/detect/train2/confusion_matrix.png', width=1000)

# %%
from IPython.display import Image

Image(filename=f'runs/detect/train2/results.png', width=1000)

# %%
import supervision as sv

ds = sv.DetectionDataset.from_yolo(
    images_directory_path=f"yolo_export/test/images",
    annotations_directory_path=f"yolo_export/test/labels",
    data_yaml_path=f"data.yaml"
)

ds.classes
# Out:
# ['CS']

# %%
from supervision.metrics import MeanAveragePrecision

model = YOLO(f'runs/detect/train2/weights/best.pt')

predictions = []
targets = []

for _, image, target in ds:
    results = model(image, verbose=False)[0]
    detections = sv.Detections.from_ultralytics(results)

    predictions.append(detections)
    targets.append(target)

map = MeanAveragePrecision().update(predictions, targets).compute()

# %%
print("mAP 50:95", map.map50_95)
print("mAP 50", map.map50)
print("mAP 75", map.map75)
# Out:
# mAP 50:95 0.04607511300580607
# mAP 50 0.09434872058634435
# mAP 75 0.03549124143183549

# %%
# %matplotlib inline

map.plot()

# %%
import supervision as sv

model = YOLO(f'runs/detect/train2/weights/best.pt')

ds = sv.DetectionDataset.from_yolo(
    images_directory_path=f"yolo_export/test/images",
    annotations_directory_path=f"yolo_export/test/labels",
    data_yaml_path=f"data.yaml"
)

# %%
import random

i = random.randint(0, len(ds))

image_path, image, target = ds[i]

results = model(image, verbose=False)[0]
detections = sv.Detections.from_ultralytics(results).with_nms()

box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator()

annotated_image = image.copy()
annotated_image = box_annotator.annotate(scene=annotated_image, detections=detections)
annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)

sv.plot_image(annotated_image)
